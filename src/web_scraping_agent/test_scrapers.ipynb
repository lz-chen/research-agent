# %% [markdown]
# https://github.com/trancethehuman/ai-workshop-code/blob/main/Web_scraping_for_LLM_in_2024.ipynb

# %% [markdown]
# ## Reader API by Jina AI

# %%
import requests

def scrape_jina_ai(url: str) -> str:
  response = requests.get("https://r.jina.ai/" + url)
  return response.text

# %% [markdown]
# ## Firecrawl from Mendable

# %%
import firecrawl
import getpass

FIRECRAWL_API_KEY = getpass.getpass("Mendable API Key: ")

def scrape_firecrawl(url: str):
    app = firecrawl.FirecrawlApp(api_key=FIRECRAWL_API_KEY)
    scraped_data = app.scrape_url(url)["markdown"]
    return scraped_data

# %% [markdown]
# ## Token Usage

# %%
import tiktoken

def count_tokens(input_string: str) -> int:
    tokenizer = tiktoken.get_encoding("cl100k_base")

    tokens = tokenizer.encode(input_string)

    return len(tokens)

def calculate_cost(input_string: str, cost_per_million_tokens: float = 5) -> float:
    num_tokens = count_tokens(input_string)

    total_cost = (num_tokens / 1_000_000) * cost_per_million_tokens

    return total_cost

# Example usage:
# input_string = "What's the difference between beer nuts and deer nuts? Beer nuts are about 5 dollars. Deer nuts are just under a buck."
# cost = calculate_cost(input_string)
# print(f"The total cost for using gpt-4o is: $US {cost:.6f}")

# %% [markdown]
# ## View Scraped Content

# %%
from typing import List, Callable, Dict
from prettytable import PrettyTable, ALL
from tqdm import tqdm

def view_scraped_content(scrape_url_functions: List[Dict[str, Callable[[str], str]]], sites_list: List[Dict[str, str]], characters_to_display: int = 500, table_max_width: int = 50) -> List[Dict[str, str]]:
    content_table_headers = ["Site Name"] + [f"{func['name']} content" for func in scrape_url_functions]
    cost_table_headers = ["Site Name"] + [f"{func['name']} cost" for func in scrape_url_functions]

    content_table = PrettyTable()
    content_table.field_names = content_table_headers

    cost_table = PrettyTable()
    cost_table.field_names = cost_table_headers

    scraped_data = []

    for site in sites_list:
        content_row = [site['name']]
        cost_row = [site['name']]
        site_data = {"provider": site['name'], "sites": []}

        for scrape_function in scrape_url_functions:
            function_name = scrape_function['name']
            for _ in tqdm([site], desc=f"Processing site {site['name']} using {function_name}"):
                try:
                    content = scrape_function['function'](site['url'])
                    content_snippet = content[:characters_to_display]
                    content_row.append(content_snippet)

                    cost = calculate_cost(content)
                    cost_row.append(f"${cost:.6f}")

                    site_data["sites"].append({"name": function_name, "content": content})
                except Exception as e:
                    error_message = f"Error: {str(e)}"
                    content_row.append(error_message)
                    cost_row.append("Error")

                    site_data["sites"].append({"name": function_name, "content": error_message})
                    continue

        content_table.add_row(content_row)
        cost_table.add_row(cost_row)
        scraped_data.append(site_data)

    content_table.max_width = table_max_width
    content_table.hrules = ALL

    cost_table.max_width = table_max_width
    cost_table.hrules = ALL

    print("Content Table:")
    print(content_table)

    print("\nCost Table:\nThis is how much it would cost to use gpt-4o to parse this content for extraction.")
    print(cost_table)

    return scraped_data

# %%
sites = [
    {"name": "Vespa", "url": "https://vespa.ai/"},
    {"name": "Rresail", "url": "https://presail.com/"},
]

# %%
list_of_scraper_functions = [
      # {"name": "Beautiful Soup", "function": beautiful_soup_scrape_url},
      {"name": "Firecrawl", "function": scrape_firecrawl},
      {"name": "Jina AI", "function": scrape_jina_ai}
      ]

all_content = view_scraped_content(list_of_scraper_functions, sites, 700, 20)
# Out:
# Processing site Vespa using Firecrawl: 100%|██████████| 1/1 [00:06<00:00,  6.50s/it]
# Processing site Vespa using Jina AI: 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]
# Processing site Rresail using Firecrawl: 100%|██████████| 1/1 [00:03<00:00,  3.87s/it]
# Processing site Rresail using Jina AI: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Content Table:
# +-----------+----------------------+----------------------+
# | Site Name |  Firecrawl content   |   Jina AI content    |
# +-----------+----------------------+----------------------+
# |   Vespa   | [![Vespa logo](https | Title: Vespa - data  |
# |           | ://vespa.ai/assets/l |     + AI, online     |
# |           |     ogo.png)](/)     |                      |
# |           |                      |     URL Source:      |
# |           | [](https://search.ve |  https://vespa.ai/   |
# |           |       spa.ai/)       |                      |
# |           |                      |  Markdown Content:   |
# |           | [Get Started](https: |  Vespa - data + AI,  |
# |           | //cloud.vespa.ai/en/ |        online        |
# |           |   getting-started)   |   ===============    |
# |           |  [Features](/feature |                      |
# |           |          s)          |                      |
# |           |                      | [![Image 1: Vespa lo |
# |           |      Solutions       | go](https://vespa.ai |
# |           |                      | /assets/logo.png)](h |
# |           | [Vespa Executive Ove |  ttps://vespa.ai/)   |
# |           |  rview](/executive-  |                      |
# |           |    overview.html)    | [](https://search.ve |
# |           |      [Unlocking      |       spa.ai/)       |
# |           |      eCommerce       |                      |
# |           | Growth](/unlocking-  | [Get Started](https: |
# |           |      ecommerce-      | //cloud.vespa.ai/en/ |
# |           |     growth.html)     | getting-started) [Fe |
# |           |                      | atures](https://vesp |
# |           |    Documentation     |    a.ai/features)    |
# |           |                      |                      |
# |           | [Vespa Overview Deck |      Solutions       |
# |           | ](https://docs.googl |                      |
# |           | e.com/presentation/d | [Vespa Executive Ove |
# |           | /1TO_QX451CUvLzI3rVM | rview](https://vespa |
# |           | cjB0qQXutUaoF6rTVfQL |    .ai/executive-    |
# |           |        rfvPg)        |    overview.html)    |
# |           |  [Vespa Documentatio | [Unlocking eCommerce |
# |           | n](https://docs.vesp | Growth](https://vesp |
# |           |        a.ai/)        |   a.ai/unlocking-    |
# |           |        [Video        |      ecommerce-      |
# |           | Archive](/resources) |     growth.html)     |
# |           |      [Vespa and      |                      |
# |           |   ElasticSearch /    |    Documentation     |
# |           |    Solr](/vespa-     |                      |
# |           |    elastic-solr)     | [Vespa Overview Deck |
# |           |                      | ](https://docs.googl |
# |           | [Blog](https://blog. | e.com/presentation/d |
# |           |      vespa.ai/)      | /1TO_QX451CUvLzI3rVM |
# |           |                      | cjB0qQXutUaoF6rTVfQL |
# |           |     Vespa Cloud      | rfvPg) [Vespa Docume |
# |           |                      | ntation](https://doc |
# |           | [Vespa Cloud](https: | s.vespa.ai/) [Video  |
# |           |  //cloud.vespa.ai/)  |    Archive](https    |
# |           |  [Vespa Cloud Consol |                      |
# |           | e](https://console.v |                      |
# |           |  espa.oath.cloud/)   |                      |
# |           |                      |                      |
# |           |       Company        |                      |
# |           |                      |                      |
# |           |                      |                      |
# +-----------+----------------------+----------------------+
# |  Rresail  |  🎉 Exciting news:   |   Title: Presail -   |
# |           |      Presail is      |      Investment      |
# |           | rebranding to Spring |  Infrastructure for  |
# |           |     – find us at     |       Web 3.0        |
# |           |   www.spring.net!    |                      |
# |           |                      |     URL Source:      |
# |           | [![](https://cdn.pro | https://presail.com/ |
# |           | d.website-files.com/ |                      |
# |           | 64dd0eb691b3ca8e6311 |  Markdown Content:   |
# |           | 9b8b/64e07c019305239 |  Real stories, real  |
# |           | d53af91ab_Logo%20Tex |       results        |
# |           | t%20center%20Aligned | -------------------- |
# |           | %2C%20but%20smaller% |        ------        |
# |           |      20(1)](/)       |                      |
# |           |                      |  “We’re very happy   |
# |           |       Products       |   about teaming up   |
# |           |                      |    with Presail.     |
# |           |   #### Operations    |   Together, we're    |
# |           |                      |  changing the game   |
# |           |    [Fundraising\     | for creators in the  |
# |           |          \           |  Ronin community by  |
# |           |     Elevate your     |  making fundraising  |
# |           |   fundraising game   |   way easier. This   |
# |           | with a perfect blend |  partnership isn’t   |
# |           |  of customizability  |      just about      |
# |           | and user-friendlines |     streamlining     |
# |           | s.](/features/fundra |  investments; it’s   |
# |           |        ising)        | about opening doors  |
# |           |     [Allocation      | to new co-investment |
# |           |     management\      |   opportunities in   |
# |           |          \           |    Ronin’s gaming    |
# |           |  Maintain a single   | projects, which is a |
# |           | source of truth for  |   big win for our    |
# |           |   all investments,   |     community.”      |
# |           |  ensuring accurate   |                      |
# |           | and up-to-date recor | ![Image 1](https://c |
# |           | ds.](/features/alloc | dn.prod.website-file |
# |           |  ation-management)   | s.com/64dd0eb691b3ca |
# |           | [Token distribution\ | 8e63119b8b/65afca759 |
# |           |          \           | d2e750359c5c20e_XOC7 |
# |           |  Distribute tokens   |  A0jy_400x400.jpg)   |
# |           |    with unmatched    |                      |
# |           | accuracy to hundreds |  Aleksander Larsen   |
# |           | of investors at the  |                      |
# |           |  click of a button.  | COO & Co-founder Sky |
# |           | Seamless, swift, and |    Mavis & Ronin     |
# |           |   spot-on every ti   |                      |
# |           |                      |   “Partnering with   |
# |           |                      |        Presa         |
# +-----------+----------------------+----------------------+
#
# Cost Table:
# This is how much it would cost to use gpt-4o to parse this content for extraction.
# +-----------+----------------+--------------+
# | Site Name | Firecrawl cost | Jina AI cost |
# +-----------+----------------+--------------+
# |   Vespa   |   $0.015235    |  $0.011560   |
# +-----------+----------------+--------------+
# |  Rresail  |   $0.020605    |  $0.009655   |
# +-----------+----------------+--------------+

# %%
print(all_content[0]["sites"][1]["content"])
# Out:
# Title: Vespa - data + AI, online
#
# URL Source: https://vespa.ai/
#
# Markdown Content:
# Vespa - data + AI, online
# ===============
#
#
# [![Image 1: Vespa logo](https://vespa.ai/assets/logo.png)](https://vespa.ai/)
#
# [](https://search.vespa.ai/)
#
# [Get Started](https://cloud.vespa.ai/en/getting-started) [Features](https://vespa.ai/features)
#
# Solutions
#
# [Vespa Executive Overview](https://vespa.ai/executive-overview.html) [Unlocking eCommerce Growth](https://vespa.ai/unlocking-ecommerce-growth.html)
#
# Documentation
#
# [Vespa Overview Deck](https://docs.google.com/presentation/d/1TO_QX451CUvLzI3rVMcjB0qQXutUaoF6rTVfQLrfvPg) [Vespa Documentation](https://docs.vespa.ai/) [Video Archive](https://vespa.ai/resources) [Vespa and ElasticSearch / Solr](https://vespa.ai/vespa-elastic-solr)
#
# [Blog](https://blog.vespa.ai/)
#
# Vespa Cloud
#
# [Vespa Cloud](https://cloud.vespa.ai/) [Vespa Cloud Console](https://console.vespa.oath.cloud/)
#
# Company
#
# [About](https://vespa.ai/team) [Jobs](https://vespa.ai/we-are-hiring) [Events](https://vespa.ai/events) [Press and news](https://vespa.ai/press)
#
# [Search](https://search.vespa.ai/) [Slack](https://join.slack.com/t/vespatalk/shared_invite/zt-nq61o73o-Lsun7Fnm5N8uA6UAfIycIg) [Github](https://github.com/vespa-engine/vespa) [Help](https://vespa.ai/support)
#
# ![Image 2: gigaom 2024 leader badge](https://vespa.ai/assets/gigaom-2024-leader-badge.png) [GigaOm Sonar for Vector Databases Positions Vespa as a Leader and Forward Mover](https://content.vespa.ai/gigaom-report-2024)
#
# Big Data + AI, online.
# ======================
#
# Apply AI to your data, online. At any scale, with unbeatable performance.
#
# [Get Started](https://cloud.vespa.ai/en/getting-started) [Watch Video](https://vespa.ai/#open-video-modal)
#
# [](https://vespa.ai/#close)
#
# [Deploy on AWS or GCP](https://cloud.vespa.ai/), or [download open source](https://docs.vespa.ai/en/getting-started.html).
#
# Companies who take their data and AI online build on Vespa
# ==========================================================
#
# [![Image 3: Spotify](https://vespa.ai/assets/logos/spotify-rnd.png)](https://engineering.atspotify.com/introducing-natural-language-search-for-podcast-episodes/)
#
# [![Image 4: Yahoo](https://vespa.ai/assets/logos/yahoo.png)](https://www.yahoo.com/)
#
# [![Image 5: Stanby](https://vespa.ai/assets/logos/stanby-logo.png)](https://blog.vespa.ai/migrating-to-the-vespa-search-engine/)
#
# [![Image 6: Qwant](https://vespa.ai/assets/logos/qwant.jpg)](https://about.qwant.com/wp-content/uploads/2022/10/20221018_Qwant-x-Vespa-EN.pdf)
#
# [![Image 7: Wix](https://vespa.ai/assets/logos/wix.png)](https://wix.com/)
#
# [![Image 8: OTTO](https://vespa.ai/assets/logos/otto.png)](https://www.otto.de/unternehmen/en/)
#
# [![Image 9: RavenPack](https://vespa.ai/assets/logos/ravenpack-logo-normal-monochrome.svg)](https://www.ravenpack.com/)
#
# [![Image 10: Elicit](https://vespa.ai/assets/logos/elicit-logo.svg)](https://elicit.com/)
#
# What is Vespa used for?
# =======================
#
# ![Image 11: Usecase illustration](https://vespa.ai/assets/text-search.svg)
#
# Search
# ------
#
# Vespa is a fully featured search engine and vector database. It supports vector search (ANN), lexical search, and search in structured data, all in the same query. Integrated machine-learned model inference allows you to apply AI to make sense of your data in real time. Together with Vespa's proven scaling and high availability, this empowers you to create production ready search applications at any scale, and with any combination of features. [more](https://vespa.ai/usecases#search)
#
# ![Image 12: Usecase illustration](https://vespa.ai/assets/text-search.svg)
#
# ![Image 13: Usecase illustration](https://vespa.ai/assets/recommendations.svg)
#
# Recommendation and personalization
# ----------------------------------
#
# Recommendation, personalization and targeting involves evaluating recommender models over content items to select the best ones. Vespa lets you build applications which do this online, typically combining fast vector search and filtering with evaluation of machine-learned models over the items. This makes it possible to make recommendations specifically for each user or situation, using completely up to date information. [more](https://vespa.ai/usecases#recommendation-and-personalization)
#
# ![Image 14: Usecase illustration](https://vespa.ai/assets/conversation.svg)
#
# Generative AI
# -------------
#
# Large language models lack information that is recent, detailed, or private to a user or organization. That's why most generative AI systems combine the LLM with a component that surfaces the most useful information for the task at hand (RAG). By integrating vector, text and structured data search, machine-learned relevance models, and powerful tensor computations, Vespa lets you do this better than any other platform, and scale easily to any amount of data and traffic. [more](https://vespa.ai/usecases#generative-ai)
#
# ![Image 15: Usecase illustration](https://vespa.ai/assets/conversation.svg)
#
# ![Image 16: Usecase illustration](https://vespa.ai/assets/structured-navigation.svg)
#
# Semi-structured navigation
# --------------------------
#
# Applications such as e-commerce use a combination of structured data and text and need to provide structured navigation - grouping data dynamically for navigation and filtering - in combination with search and recommendation. Vespa provides all the features required for this with great performance, which makes it possible to realize functionally complete applications leveraging structured data on a unified architecture. [more](https://vespa.ai/usecases#semi-structured-navigation)
#
# [More use cases](https://vespa.ai/usecases#personal-search)
#
# Structured, text & vector search
# --------------------------------
#
# Combine search in structured data, text and vectors in one query to achieve functionality and performance which is simply impossible with other technologies.
#
# [Learn More](https://vespa.ai/features#query-capabilities)
#
# Machine learning support
# ------------------------
#
# Vespa is engineered around scalable and efficient support for machine-learned model inference, and supports most machine-learned models from most tools.
#
# [Learn More](https://vespa.ai/features#computation-engine)
#
# Auto-elastic data management
# ----------------------------
#
# Vespa will automatically keep data distributed over nodes, and redistribute in the background on changes. No need to worry about how data is divided and distributed.
#
# [Learn More](https://vespa.ai/features#operability-and-data-management)
#
# Unbeatable end-to-end performance
# ---------------------------------
#
# Vespa scales to any amount of data and traffic, and is built on a C++ core providing hardware-near optimizations and efficient utilization of any amount of memory and cores.
#
# [Learn More](https://vespa.ai/features#performance-and-scalability)
#
# [Matryoshka 🤝 Binary vectors: Slash vector search costs with Vespa ------------------------------------------------------------------ ![Image 17: Image of author](https://blog.vespa.ai/assets/avatars/jobergum.jpg) #### Jo Kristian Bergum 22 Apr 2024](https://blog.vespa.ai/combining-matryoshka-with-binary-quantization-using-embedder/)
#
# [Vespa Newsletter, April 2024 ---------------------------- ![Image 18: Image of author](https://blog.vespa.ai/assets/avatars/kkraune.jpg) #### Kristian Aune 15 Apr 2024](https://blog.vespa.ai/vespa-newsletter-april-2024/)
#
# [Farfetch: Scaling recommendations with Vespa -------------------------------------------- ![Image 19: Image of author](https://blog.vespa.ai/assets/avatars/bratseth.jpg) #### Jon Bratseth 10 Apr 2024](https://blog.vespa.ai/farfetch-scaling-recommendations-with-vespa/)
#
# [Marqo chooses Vespa ------------------- ![Image 20: Image of author](https://blog.vespa.ai/assets/avatars/bratseth.jpg) #### Jon Bratseth 08 Apr 2024](https://blog.vespa.ai/marqo-chooses-vespa/)
#
# [View more blogs](https://blog.vespa.ai/)
#
# Get Started today
# =================
#
# Vespa lets you do selection, organization and machine-learned model inference over billions of constantly changing data items, serving thousands of queries per second with latency below 100 milliseconds.
#
# Get started today for free.
#
# [Get Started](https://cloud.vespa.ai/en/getting-started)
#
# Resources
#
# [Documentation](https://docs.vespa.ai/)
# [Open Source](https://github.com/vespa-engine/vespa)
# [Roadmap](https://vespa.ai/roadmap)
# [Releases](https://vespa.ai/releases)
# [Issues](https://github.com/vespa-engine/vespa/issues)
# [Privacy Policy](https://vespa.ai/product-terms/privacy-policy)
#
# Contact
#
# [Twitter](https://twitter.com/vespaengine)
# [info@vespa.ai](mailto:info@vespa.ai)
# [Vespa.ai team](https://vespa.ai/team)
# [We are hiring!](https://vespa.ai/we-are-hiring)
# [Mailing list](https://vespa.ai/mailing-list)
#
# Community
#
# [Slack](https://join.slack.com/t/vespatalk/shared_invite/zt-nq61o73o-Lsun7Fnm5N8uA6UAfIycIg)
# [Stack Overflow](https://stackoverflow.com/questions/tagged/vespa)
# [Contributing](https://github.com/vespa-engine/vespa/blob/master/CONTRIBUTING.md)
# [Blog](https://blog.vespa.ai/)
#
# ###### Copyright Vespa.ai

# %%
from pprint import pprint
pprint(all_content[0]["sites"][0]["content"])
# Out:
# ('[![Vespa logo](https://vespa.ai/assets/logo.png)](/)\n'
#  '\n'
#  '[](https://search.vespa.ai/)\n'
#  '\n'
#  '[Get Started](https://cloud.vespa.ai/en/getting-started)\n'
#  ' [Features](/features)\n'
#  '\n'
#  'Solutions\n'
#  '\n'
#  '[Vespa Executive Overview](/executive-overview.html)\n'
#  ' [Unlocking eCommerce Growth](/unlocking-ecommerce-growth.html)\n'
#  '\n'
#  'Documentation\n'
#  '\n'
#  '[Vespa Overview '
#  'Deck](https://docs.google.com/presentation/d/1TO_QX451CUvLzI3rVMcjB0qQXutUaoF6rTVfQLrfvPg)\n'
#  ' [Vespa Documentation](https://docs.vespa.ai/)\n'
#  ' [Video Archive](/resources)\n'
#  ' [Vespa and ElasticSearch / Solr](/vespa-elastic-solr)\n'
#  '\n'
#  '[Blog](https://blog.vespa.ai/)\n'
#  '\n'
#  'Vespa Cloud\n'
#  '\n'
#  '[Vespa Cloud](https://cloud.vespa.ai/)\n'
#  ' [Vespa Cloud Console](https://console.vespa.oath.cloud/)\n'
#  '\n'
#  'Company\n'
#  '\n'
#  '[About](/team)\n'
#  ' [Jobs](/we-are-hiring)\n'
#  ' [Events](/events)\n'
#  ' [Press and news](/press)\n'
#  '\n'
#  '[Search](https://search.vespa.ai/)\n'
#  ' '
#  '[Slack](https://join.slack.com/t/vespatalk/shared_invite/zt-nq61o73o-Lsun7Fnm5N8uA6UAfIycIg)\n'
#  ' [Github](https://github.com/vespa-engine/vespa)\n'
#  ' [Help](/support)\n'
#  '\n'
#  '![gigaom 2024 leader '
#  'badge](https://vespa.ai/assets/gigaom-2024-leader-badge.png) [GigaOm Sonar '
#  'for Vector Databases Positions Vespa as a Leader and Forward '
#  'Mover](https://content.vespa.ai/gigaom-report-2024)\n'
#  '\n'
#  'Big Data + AI, online.\n'
#  '======================\n'
#  '\n'
#  'Apply AI to your data, online. At any scale, with unbeatable performance.\n'
#  '\n'
#  '[Get Started](https://cloud.vespa.ai/en/getting-started)\n'
#  ' [Watch Video](#open-video-modal)\n'
#  '\n'
#  '[](#close)\n'
#  '\n'
#  '[Deploy on AWS or GCP](https://cloud.vespa.ai)\n'
#  ', or [download open source](https://docs.vespa.ai/en/getting-started.html)\n'
#  '.\n'
#  '\n'
#  'Companies who take their data and AI online build on Vespa\n'
#  '==========================================================\n'
#  '\n'
#  '[![Spotify](https://vespa.ai/assets/logos/spotify-rnd.png%20%22When%20Spotify%20wanted%20to%20implement%20semantic%20search%20using%20vector%20embeddings,%20they%20turned%20to%20Vespa%20for%20its%20support%20for%20fast%20ANN%20search%20in%20combination%20with%20all%20the%20other%20needs%20of%20real%20applications,%20such%20as%20using%20ranking%20functions%20combining%20vector%20similarity%20with%20other%20signals.%22)](https://engineering.atspotify.com/introducing-natural-language-search-for-podcast-episodes/)\n'
#  '\n'
#  '[![Yahoo](https://vespa.ai/assets/logos/yahoo.png%20%22Yahoo%20runs%20about%20150%20Vespa%20applications,%20including%20selecting%20the%20personalized%20content%20on%20all%20content%20pages%20in%20real%20time%20and%20the%20targeted%20ads%20of%20one%20of%20the%20worlds%20largest%20ad%20exchanges.%20In%20total%20these%20applications%20serve%20close%20to%20a%20billion%20users,%20at%20a%20rate%20of%20600%20000%20queries%20per%20second.%22)](https://www.yahoo.com/)\n'
#  '\n'
#  '[![Stanby](https://vespa.ai/assets/logos/stanby-logo.png%20%22Hello,%20I%20am%20Satoshi%20Takatori,%20in%20charge%20of%20search-related%20development%20at%20Stanby.%20In%20this%20post,%20I%20will%20detail%20the%20journey%20of%20how%20we%20have%20addressed%20the%20challenges%20faced%20by%20our%20existing%20search%20system%20through%20migrating%20to%20Vespa.%20This%20is%20the%20English%20version%20of%20an%20article%20originally%20published%20on%20the%20Stanby%20Tech%20Blog.%22)](https://blog.vespa.ai/migrating-to-the-vespa-search-engine/)\n'
#  '\n'
#  '[![Qwant](https://vespa.ai/assets/logos/qwant.jpg%20%22Qwant%20and%20Vespa.ai:%20a%20stronger%20collaboration%20in%20a%20continuous%20process%20of%20improving%20the%20search%20engine%20developed%20by%20Qwant.%22)](https://about.qwant.com/wp-content/uploads/2022/10/20221018_Qwant-x-Vespa-EN.pdf)\n'
#  '\n'
#  '[![Wix](https://vespa.ai/assets/logos/wix.png)](https://wix.com)\n'
#  '\n'
#  '[![OTTO](https://vespa.ai/assets/logos/otto.png%20%22OTTO,%20the%20largest%20German%20online%20retailer,%20runs%20its%20autosuggest%20on%20Vespa.%20Vespa%20has%20enabled%20OTTO%20to%20easily%20implement%20not%20only%20model-supported%20reranking,%20but%20also%20semantic%20retrieval%20using%20embeddings%20in%20a%20highly%20scalable%20and%20low-latency%20environment.%22)](https://www.otto.de/unternehmen/en/)\n'
#  '\n'
#  "[![RavenPack](https://vespa.ai/assets/logos/ravenpack-logo-normal-monochrome.svg%20%22RavenPack%20processes%20millions%20of%20documents%20daily.%20Vespa's%20hybrid%20search%20capabilities%20ensure%20that%20our%20clients%20receive%20up-to-date,%20relevant,%20and%20accurate%20information%20seamlessly.%20Vespa's%20efficiency%20and%20adaptability%20have%20allowed%20us%20to%20maintain%20high%20service%20and%20accuracy%20standards%20in%20an%20ever-evolving%20landscape.%22)](https://www.ravenpack.com/)\n"
#  '\n'
#  '[![Elicit](https://vespa.ai/assets/logos/elicit-logo.svg)](https://elicit.com/)\n'
#  '\n'
#  'What is Vespa used for?\n'
#  '=======================\n'
#  '\n'
#  '![Usecase illustration](https://vespa.ai/assets/text-search.svg)\n'
#  '\n'
#  'Search\n'
#  '------\n'
#  '\n'
#  'Vespa is a fully featured search engine and vector database. It supports '
#  'vector search (ANN), lexical search, and search in structured data, all in '
#  'the same query. Integrated machine-learned model inference allows you to '
#  "apply AI to make sense of your data in real time. Together with Vespa's "
#  'proven scaling and high availability, this empowers you to create production '
#  'ready search applications at any scale, and with any combination of '
#  'features. [more](usecases#search)\n'
#  '\n'
#  '![Usecase illustration](https://vespa.ai/assets/text-search.svg)\n'
#  '\n'
#  '![Usecase illustration](https://vespa.ai/assets/recommendations.svg)\n'
#  '\n'
#  'Recommendation and personalization\n'
#  '----------------------------------\n'
#  '\n'
#  'Recommendation, personalization and targeting involves evaluating '
#  'recommender models over content items to select the best ones. Vespa lets '
#  'you build applications which do this online, typically combining fast vector '
#  'search and filtering with evaluation of machine-learned models over the '
#  'items. This makes it possible to make recommendations specifically for each '
#  'user or situation, using completely up to date information. '
#  '[more](usecases#recommendation-and-personalization)\n'
#  '\n'
#  '![Usecase illustration](https://vespa.ai/assets/conversation.svg)\n'
#  '\n'
#  'Generative AI\n'
#  '-------------\n'
#  '\n'
#  'Large language models lack information that is recent, detailed, or private '
#  "to a user or organization. That's why most generative AI systems combine the "
#  'LLM with a component that surfaces the most useful information for the task '
#  'at hand (RAG). By integrating vector, text and structured data search, '
#  'machine-learned relevance models, and powerful tensor computations, Vespa '
#  'lets you do this better than any other platform, and scale easily to any '
#  'amount of data and traffic. [more](usecases#generative-ai)\n'
#  '\n'
#  '![Usecase illustration](https://vespa.ai/assets/conversation.svg)\n'
#  '\n'
#  '![Usecase illustration](https://vespa.ai/assets/structured-navigation.svg)\n'
#  '\n'
#  'Semi-structured navigation\n'
#  '--------------------------\n'
#  '\n'
#  'Applications such as e-commerce use a combination of structured data and '
#  'text and need to provide structured navigation - grouping data dynamically '
#  'for navigation and filtering - in combination with search and '
#  'recommendation. Vespa provides all the features required for this with great '
#  'performance, which makes it possible to realize functionally complete '
#  'applications leveraging structured data on a unified architecture. '
#  '[more](usecases#semi-structured-navigation)\n'
#  '\n'
#  '[More use cases](usecases#personal-search)\n'
#  '\n'
#  'Structured, text & vector search\n'
#  '--------------------------------\n'
#  '\n'
#  'Combine search in structured data, text and vectors in one query to achieve '
#  'functionality and performance which is simply impossible with other '
#  'technologies.\n'
#  '\n'
#  '[Learn More](features#query-capabilities)\n'
#  '\n'
#  'Machine learning support\n'
#  '------------------------\n'
#  '\n'
#  'Vespa is engineered around scalable and efficient support for '
#  'machine-learned model inference, and supports most machine-learned models '
#  'from most tools.\n'
#  '\n'
#  '[Learn More](features#computation-engine)\n'
#  '\n'
#  'Auto-elastic data management\n'
#  '----------------------------\n'
#  '\n'
#  'Vespa will automatically keep data distributed over nodes, and redistribute '
#  'in the background on changes. No need to worry about how data is divided and '
#  'distributed.\n'
#  '\n'
#  '[Learn More](features#operability-and-data-management)\n'
#  '\n'
#  'Unbeatable end-to-end performance\n'
#  '---------------------------------\n'
#  '\n'
#  'Vespa scales to any amount of data and traffic, and is built on a C++ core '
#  'providing hardware-near optimizations and efficient utilization of any '
#  'amount of memory and cores.\n'
#  '\n'
#  '[Learn More](features#performance-and-scalability)\n'
#  '\n'
#  '[Matryoshka 🤝 Binary vectors: Slash vector search costs with Vespa\\\n'
#  '------------------------------------------------------------------\\\n'
#  '\\\n'
#  '![Image of author](https://blog.vespa.ai/assets/avatars/jobergum.jpg)\\\n'
#  '\\\n'
#  '#### Jo Kristian Bergum\\\n'
#  '\\\n'
#  '22 Apr '
#  '2024](https://blog.vespa.ai/combining-matryoshka-with-binary-quantization-using-embedder/)\n'
#  '\n'
#  '[Vespa Newsletter, April 2024\\\n'
#  '----------------------------\\\n'
#  '\\\n'
#  '![Image of author](https://blog.vespa.ai/assets/avatars/kkraune.jpg)\\\n'
#  '\\\n'
#  '#### Kristian Aune\\\n'
#  '\\\n'
#  '15 Apr 2024](https://blog.vespa.ai/vespa-newsletter-april-2024/)\n'
#  '\n'
#  '[Farfetch: Scaling recommendations with Vespa\\\n'
#  '--------------------------------------------\\\n'
#  '\\\n'
#  '![Image of author](https://blog.vespa.ai/assets/avatars/bratseth.jpg)\\\n'
#  '\\\n'
#  '#### Jon Bratseth\\\n'
#  '\\\n'
#  '10 Apr '
#  '2024](https://blog.vespa.ai/farfetch-scaling-recommendations-with-vespa/)\n'
#  '\n'
#  '[Marqo chooses Vespa\\\n'
#  '-------------------\\\n'
#  '\\\n'
#  '![Image of author](https://blog.vespa.ai/assets/avatars/bratseth.jpg)\\\n'
#  '\\\n'
#  '#### Jon Bratseth\\\n'
#  '\\\n'
#  '08 Apr 2024](https://blog.vespa.ai/marqo-chooses-vespa/)\n'
#  '\n'
#  '[View more blogs](https://blog.vespa.ai)\n'
#  '\n'
#  'Get Started today\n'
#  '=================\n'
#  '\n'
#  'Vespa lets you do selection, organization and machine-learned model '
#  'inference over billions of constantly changing data items, serving thousands '
#  'of queries per second with latency below 100 milliseconds.\n'
#  '\n'
#  'Get started today for free.\n'
#  '\n'
#  '[Get Started](https://cloud.vespa.ai/en/getting-started)\n'
#  '\n'
#  'Resources\n'
#  '\n'
#  '[Documentation](https://docs.vespa.ai/)\n'
#  '  \n'
#  '[Open Source](https://github.com/vespa-engine/vespa)\n'
#  '  \n'
#  '[Roadmap](/roadmap)\n'
#  '  \n'
#  '[Releases](/releases)\n'
#  '  \n'
#  '[Issues](https://github.com/vespa-engine/vespa/issues)\n'
#  '  \n'
#  '[Privacy Policy](https://vespa.ai/product-terms/privacy-policy)\n'
#  '  \n'
#  '\n'
#  'Contact\n'
#  '\n'
#  '[Twitter](https://twitter.com/vespaengine)\n'
#  '  \n'
#  '[info@vespa.ai](mailto:info@vespa.ai)\n'
#  '  \n'
#  '[Vespa.ai team](/team)\n'
#  '  \n'
#  '[We are hiring!](/we-are-hiring)\n'
#  '  \n'
#  '[Mailing list](/mailing-list)\n'
#  '  \n'
#  '\n'
#  'Community\n'
#  '\n'
#  '[Slack](https://join.slack.com/t/vespatalk/shared_invite/zt-nq61o73o-Lsun7Fnm5N8uA6UAfIycIg)\n'
#  '  \n'
#  '[Stack Overflow](https://stackoverflow.com/questions/tagged/vespa)\n'
#  '  \n'
#  '[Contributing](https://github.com/vespa-engine/vespa/blob/master/CONTRIBUTING.md)\n'
#  '  \n'
#  '[Blog](https://blog.vespa.ai/)\n'
#  '  \n'
#  '\n'
#  '###### Copyright Vespa.ai\n'
#  '\n'
#  'Yahoo Developer Network\n'
#  '\n'
#  '2.49K subscribers\n'
#  '\n'
#  '[Vespa - Open Source Big Data Serving Engine, Jon Bratseth, Distinguished '
#  'Architect, Verizon Media](https://www.youtube.com/watch?v=V3c5p2JopzQ)\n'
#  '\n'
#  'Yahoo Developer Network\n'
#  '\n'
#  'Search\n'
#  '\n'
#  'Info\n'
#  '\n'
#  'Shopping\n'
#  '\n'
#  'Tap to unmute\n'
#  '\n'
#  "If playback doesn't begin shortly, try restarting your device.\n"
#  '\n'
#  'Share\n'
#  '\n'
#  'Include playlist\n'
#  '\n'
#  'An error occurred while retrieving sharing information. Please try again '
#  'later.\n'
#  '\n'
#  'Watch later\n'
#  '\n'
#  'Share\n'
#  '\n'
#  'Copy link\n'
#  '\n'
#  'Watch on\n'
#  '\n'
#  '0:00\n'
#  '\n'
#  '/ •Live\n'
#  '\n'
#  '•\n'
#  '\n'
#  '[](https://www.youtube.com/watch?v=V3c5p2JopzQ "Watch on YouTube")')

# %% [markdown]
# ## Extracting Entities from web content with Azure OpenAI

# %%
import os
import openai
import dotenv

dotenv.load_dotenv(".env")
# Out:
# True

# %%
endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
api_key = os.environ["AZURE_OPENAI_API_KEY"]
chat_model = os.environ["AZURE_OPENAI_CHAT_MODEL"]
api_version = os.environ["AZURE_OPENAI_API_VERSION"]

client = openai.AzureOpenAI(
    azure_endpoint=endpoint,
    api_key=api_key,
    api_version=api_version
)

# %%
sys_msg_comp_overview = """Get me the main information about the company, including their goal, detailed summary of the company, established time, the link to the page which contains information about the members of the company (usually a site within the same domain). Return as a JSON with four keys: {company_goal: str, company_summary: str, established_time: str, members_page: str}."""

# %%
def extract(user_input: str, system_message: str):
  entity_extraction_system_message = {"role": "system", "content": system_message}
  messages = [entity_extraction_system_message]
  messages.append({"role": "user", "content": user_input})

  response = client.chat.completions.create(
        model="gpt-4o",
        messages=messages,
        stream=False,
        response_format={"type": "json_object"}
    )

  return response.choices[0].message.content

# %%
def display_extracted_content(results: List[Dict[str, any]], num_objects: int):
    table = PrettyTable()
    table.field_names = ["Site", "Provider Name", "Extracted Content"]

    # Ensure num_objects does not exceed the length of the results list
    num_objects = min(num_objects, len(results))

    # Process the specified number of items from the results list with a progress bar
    for result in tqdm(results[:num_objects], desc="Processing results"):
        provider_name = result["provider"]

        for site in result["sites"]:
            function_name = site["name"]
            content = site["content"]

            # Progress bar for each function
            for _ in tqdm(range(1), desc=f"Extracting content with {provider_name} for {function_name}"):
                extracted_content = extract(content, sys_msg_comp_overview)
                table.add_row([provider_name, function_name, extracted_content])

    table.max_width = 50  # Set the maximum width for better display
    table.hrules = ALL

    print("Extracted Content Table:")
    print(table)

# %%
display_extracted_content(all_content, num_objects=9)
# Out:
# Processing results:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting content with Vespa for Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Vespa for Firecrawl: 100%|██████████| 1/1 [00:03<00:00,  3.54s/it]
#
# Extracting content with Vespa for Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Vespa for Jina AI: 100%|██████████| 1/1 [00:03<00:00,  3.87s/it]
# Processing results:  50%|█████     | 1/2 [00:07<00:07,  7.42s/it]
# Extracting content with Rresail for Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Rresail for Firecrawl: 100%|██████████| 1/1 [00:03<00:00,  3.43s/it]
#
# Extracting content with Rresail for Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Rresail for Jina AI: 100%|██████████| 1/1 [00:03<00:00,  3.99s/it]
# Processing results: 100%|██████████| 2/2 [00:14<00:00,  7.42s/it]
# Extracted Content Table:
# +---------+---------------+----------------------------------------------------+
# |   Site  | Provider Name |                 Extracted Content                  |
# +---------+---------------+----------------------------------------------------+
# |  Vespa  |   Firecrawl   |                         {                          |
# |         |               |   "company_goal": "Apply AI to your data, online.  |
# |         |               |    At any scale, with unbeatable performance.",    |
# |         |               |    "company_summary": "Vespa is a fully featured   |
# |         |               |  search engine and vector database that supports   |
# |         |               | vector search (ANN), lexical search, and search in |
# |         |               |     structured data, all in the same query. It     |
# |         |               | integrates machine-learned model inference to make |
# |         |               | sense of data in real-time, providing capabilities |
# |         |               |     for production-ready search applications,      |
# |         |               | recommendation and personalization, generative AI, |
# |         |               | and semi-structured navigation. Vespa is built to  |
# |         |               |  scale with high performance, supporting machine   |
# |         |               |  learning, auto-elastic data management, and end-  |
# |         |               |         to-end performance optimization.",         |
# |         |               |    "established_time": "Information not provided   |
# |         |               |            directly within the text.",             |
# |         |               |       "members_page": "https://vespa.ai/team"      |
# |         |               |                         }                          |
# +---------+---------------+----------------------------------------------------+
# |  Vespa  |    Jina AI    |                         {                          |
# |         |               |   "company_goal": "Apply AI to your data, online.  |
# |         |               |    At any scale, with unbeatable performance.",    |
# |         |               |    "company_summary": "Vespa is a fully featured   |
# |         |               |   search engine and vector database. It supports   |
# |         |               | vector search (ANN), lexical search, and search in |
# |         |               | structured data, all in the same query. Integrated |
# |         |               |   machine-learned model inference allows you to    |
# |         |               | apply AI to make sense of your data in real time.  |
# |         |               |       Vespa lets you build applications for        |
# |         |               | recommendation, personalization, and generative AI |
# |         |               |   with powerful tensor computations, and scales    |
# |         |               |  easily to any amount of data and traffic. It is   |
# |         |               |   suitable for applications requiring structured   |
# |         |               | navigation and unified architecture for combining  |
# |         |               | structured data, text, and vectors, providing high |
# |         |               |           performance and scalability.",           |
# |         |               |    "established_time": "The specific established   |
# |         |               |   time was not provided in the given document.",   |
# |         |               |       "members_page": "https://vespa.ai/team"      |
# |         |               |                         }                          |
# +---------+---------------+----------------------------------------------------+
# | Rresail |   Firecrawl   |                         {                          |
# |         |               |   "company_goal": "To unify all aspects of Web 3.0 |
# |         |               |  investments in one platform—from fundraising and  |
# |         |               |    allocation management to token distribution,    |
# |         |               |           compliance, and OTC trading.",           |
# |         |               |    "company_summary": "Spring (formerly Presail)   |
# |         |               | offers a comprehensive suite of products aimed at  |
# |         |               |  simplifying and enhancing the investment process  |
# |         |               | in the Web 3.0 ecosystem. Their offerings include  |
# |         |               |   customizable fundraising solutions, allocation   |
# |         |               |       management, token distribution, an OTC       |
# |         |               |   marketplace, and an investor portal. They also   |
# |         |               |  provide compliance services to automate KYC/AML   |
# |         |               |   processes and facilitate seamless imports from   |
# |         |               |    manual setups. Their aim is to eliminate the    |
# |         |               |  complexity involved in managing investments and   |
# |         |               |  provide a seamless, user-friendly experience for  |
# |         |               |  investment groups, blockchains, and projects.",   |
# |         |               |             "established_time": "2021",            |
# |         |               |    "members_page": "https://www.spring.net/about-  |
# |         |               |                        us"                         |
# |         |               |                         }                          |
# +---------+---------------+----------------------------------------------------+
# | Rresail |    Jina AI    |                                                    |
# |         |               |                         {                          |
# |         |               |      "company_goal": "To provide an automated,     |
# |         |               |  secure, and efficient fundraising and investment  |
# |         |               | infrastructure for Web 3.0, enabling creators and  |
# |         |               |   companies to manage and scale their investment   |
# |         |               |              activities seamlessly.",              |
# |         |               |   "company_summary": "Presail offers an all-in-one |
# |         |               |  platform for Web 3.0 companies to automate their  |
# |         |               |  fundraising processes, manage investor data, and  |
# |         |               |  ensure compliance with KYC/AML regulations. The   |
# |         |               |  platform simplifies tasks traditionally managed   |
# |         |               |  via spreadsheets, such as allocation management   |
# |         |               | and token distribution, by offering a centralized  |
# |         |               |  hub that caters to a wide variety of needs—from   |
# |         |               | investor eligibility and customizable campaigns to |
# |         |               |  secure fund collection and real-time investment   |
# |         |               |   tracking. As a trusted partner for large-scale   |
# |         |               |  projects, Presail provides a secure and reliable  |
# |         |               | solution tailored to the unique demands of Web 3.0 |
# |         |               |                   fundraising.",                   |
# |         |               |     "established_time": "The exact establishment   |
# |         |               |   time is not mentioned in the provided content.   |
# |         |               | Please refer to the company's homepage or extended |
# |         |               |          sources for this information.",           |
# |         |               |    "members_page": "https://presail.com/about-us"  |
# |         |               |                         }                          |
# +---------+---------------+----------------------------------------------------+

# %% [markdown]
# ## Agentic Workflow for scraping member information

# %%
# Out:
# Thought: The current language of the user is English. I need to use a tool to help me answer the question.
# Action: parse_member_page
# Action Input: {'page_url': 'https://presail.com/about-us'}
# [![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e07c019305239d53af91ab_Logo%20Text%20center%20Aligned%2C%20but%20smaller%20(1)](/)
#
# Products
#
# #### Operations
#
# [Fundraising\
# \
# Elevate your fundraising game with a perfect blend of customizability and user-friendliness.](/features/fundraising)
# [Allocation management\
# \
# Maintain a single source of truth for all investments, ensuring accurate and up-to-date records.](/features/allocation-management)
# [Token distribution\
# \
# Distribute tokens with unmatched accuracy to hundreds of investors at the click of a button. Seamless, swift, and spot-on every time.](/features/token-vesting)
# [OTC marketplace\
# \
# Enable seamless trading of allocations, offering your investors liquidity while generating passive revenue through commissions.](/features/otc-marketplace)
# [Investor portal\
# \
# Empower your investors with a centralized hub to manage and track their investments.](/features/investor-portal)
#
# #### Back office
#
# [Compliance\
# \
# Streamline your KYC, AML, and more with automated background screenings, ensuring effortless and thorough investor validation.](/features/compliance)
# [Imports\
# \
# Seamlessly transition from manual setups to Presail with intuitive spreadsheet imports, unlocking all our advanced features.](/features/import)
#
# #### Featured
#
# [![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64fac676ecc183a3ddc021d8_watch-demo%20(1)\
# \
# Product tour\
# \
# Get a quick overview of the Presail platform and its functionality in this 5 min video tour.\
# \
# Watch now](/video-demo)
# [![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f737af53f0d8d7f364ef22_whitepaper-cover.webp)\
# \
# Whitepaper: What is investment infrastructure?\
# \
# The Presail whitepaper. Exploring the future of finance, and the importance of investment infrastructure.\
# \
# Read more](/blog/what-is-investment-infrastructure-for-web-3-0)
#
# Use cases
#
# **Use cases**
#
# [Investment groups\
# \
# Learn how investment groups automate their entire workflow with Presail.](/use-cases/investment-groups)
#
# [Blockchains\
# \
# Increase adoption and MAU by making Presail your investment layer.](/use-cases/blockchains)
#
# [Projects\
# \
# Learn how projects effortlessly manage their token.](/use-cases/projects)
#
# [Case studies](/case-studies)
# [Help center](https://help.presail.com/en/)
# [Careers](https://careers.presail.com/)
#
# [Apply for access](#)
# [Watch demo](/video-demo)
#
# Giving people access
# to the private market
# ============================================
#
# Our story
#
# Why we’re doing this
# --------------------
#
# Crypto has made everybody an investor, significantly accelerating a broader trend toward democratized, decentralized, and community-driven investments. This enables individuals to leverage their audiences to become fund managers. Imagine a world where anyone can guide investment decisions - not just big, old, and slow institutions. It's a world where investing is open to all, shaped by communities.
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e5f68fa7366bafa1149a3e_64e12cc76813d3c7e4134626_annie-spratt-QckxruozjRg-unsplash-_1_%20(1)
#
# We build based on what should be, not what others are doing.
# ------------------------------------------------------------
#
# Our founders are Web 3.0 veterans with seven years of hands-on experience in crypto investments, including over 400 presale deals. This experience provides us with deep insight into the unique challenges and opportunities in the space. To date, we've secured over $5 million in funding from notable venture capital firms like Kraken Ventures, GFC, SNÖ, Skyfall, and Weekend Fund. Our roster of angels also includes respected individual investors, such as the CEO of AngelList and the founders of Sky Mavis, among others.
#
# 500+
#
# Projects funded
#
# $300M
#
# Invested
#
# 90,000+
#
# Investors
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/6500196d1d7831d93c73ace7_moon.webp)
#
# ### The smartest Web 3.0 teams use Presail_’_s infrastructure to scale
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/654e488c560c58a1f998b603_yay%20network.svg)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/6661fd473edcbf619b51ac1d_Animoca%20Brands%20Logo%20-%20Standard%20(Pentaceros)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f700fe0b265d7649a25073_image%20(1)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f7010dc0924c4cd6b97d91_image%20(2)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/65afcdac2672c1cf166958d2_ronin.webp)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/65b8eb2b29b28cb01bd38224_logo%20(white)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/65afcdd4a91da132730ee125_sky%20mavis.webp)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f701410b265d7649a2a18f_image%20(8)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/65f311b3f00a71cf36c4d9cd_UnrealCapital_logo_vector_1-modified%20(1)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f70132273ee0de389b1239_image%20(7)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f7024d075328dd7f1f2777_image%20(9)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f7037d5c573999087493b7_image%20(16)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f703a3655643080ae0fe1f_image%20(18)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f702629e370b582231d62c_image%20(10)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/65afcdd4a91da132730ee125_sky%20mavis.webp)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f7028ab8c131d297941617_Bigger%20Than%20Race.png)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f7029ce1617701d373bf87_GAV.png)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f702ad697c43ab347a25d5_image%20(12)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f702c358f8549356ebe294_image%20(13)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f702d33ba2cd66ef9721be_image%20(14)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f702e642744c3bb7cc9682_image%20(15)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f703ca58f8549356ed036a_image%20(23)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64f703b78e6a42c5a8196362_image%20(19)
#
# Our values
#
# More than words: values that drive our actions
# ----------------------------------------------
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e0d8c4504cdbdee42d125d_CarbonChat.svg)
#
# ### Courage
#
# Speak your mind, even when it's not the popular opinion. We value open dialogue and critical thinking.
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e0d338adf760339f5ce1ff_CarbonCognitive.svg)
#
# ### Curious
#
# Actively strive to understand our goals, our market, and our customers. An inquisitive mind is a growing one.
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e0d36afca9a83bf64a466c_CarbonGrowth.svg)
#
# ### Impact
#
# Show a results-oriented approach and consistently perform at a high level. We're here to make a difference.
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e0d7e0b87cba886fe7dae4_CarbonDataVis3.svg)
#
# ### Judgment
#
# Make decisions that look beyond the surface to identify root issues. Effective problem-solving starts with deep understanding.
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e0d856a682fc87d4dc03a9_CarbonUserFavoriteAlt.svg)
#
# ### Honest
#
# Admit mistakes promptly and engage in straightforward communication, especially during disagreements.
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e0d269ae39386939a86d39_CarbonFaceSatisfied.svg)
#
# ### Selfless
#
# Put the best ideas first, not your ego. Collaboration thrives when we seek excellence over credit.
#
# Our team
# --------
#
# Join a team where your contributions will directly shape our product and make a lasting, visible impact.
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/667b221268a6d679eb835780_michelle-modified.jpg)
#
# Michelle
#
# Head of Content
#
# [](https://www.linkedin.com/in/michellejunewu/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/666a997a9fddc5b35c450555_1516890828720-modified.jpeg)
#
# Emmanuel
#
# Senior Developer
#
# [](https://www.linkedin.com/in/cousinemmanuel/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/6658f9a5244903316b9065d9_1618930232421-modified.jpeg)
#
# Dan
#
# Senior Developer
#
# [](https://www.linkedin.com/in/danbrooking)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/660a6727b397cf1a23938852_1631792623363%20(1)
#
# Anna
#
# Principal Recruiter
#
# [](https://www.linkedin.com/in/anna-serbo-/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/65a06889f1966dc44567e803_haakon.webp)
#
# Håkon
#
# Customer Success
#
# [](https://www.linkedin.com/in/h%C3%A5kon-%C3%B8verby-64534a22b/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/6570c8410a350a8cc919ec7e_glen.webp)
#
# Glen
#
# Senior Frontend Developer
#
# [](https://www.linkedin.com/in/glen-curtis-562439117/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e12afb23c12e65cecd9ca7_pablo-modified.jpeg)
#
# Pablo
#
# Web 3 Domain Specialist
#
# [](https://www.linkedin.com/in/pabloruizdotco/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e12b0de5ca48456f5bd445_maral-modified.jpeg)
#
# Maral
#
# Head of Compliance
#
# [](https://www.linkedin.com/in/maral-mirshahi-a1394440/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e12b176e4ab56924597249_tomas-modified.jpeg)
#
# Tomas
#
# CTO
#
# [](https://www.linkedin.com/in/tomas-veiden/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e12b22e5ca48456f5bec15_hamza.jpeg)
#
# Hamza
#
# Head of Product
#
# [](https://www.linkedin.com/in/hamzanebolsi/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e12b2c4e16c7cabade9e69_xurxo-modified.jpeg)
#
# Xurxo
#
# Principal Developer
#
# [](https://www.linkedin.com/in/xurxomendezperez/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e12b3ac2f5ca5cc40e7a09_milad.jpeg)
#
# Milad
#
# COO
#
# [](https://www.linkedin.com/in/milad-mirshahi/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e12b43f6f60b8a14a8191a_august-modified.jpeg)
#
# August
#
# Senior Developer
#
# [](https://www.linkedin.com/in/august-haug-hem-74036b5a/)
#
# ![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e12b593df2a4e6093fe863_sebastian-modified.jpeg)
#
# Sebastian
#
# CEO
#
# [](https://www.linkedin.com/in/sebastianalmnes/)
#
# [![](https://cdn.prod.website-files.com/64dd0eb691b3ca8e63119b8b/64e07c019305239d53af91ab_Logo%20Text%20center%20Aligned%2C%20but%20smaller%20(1)](/)
#
# Products
#
# [Fundraising](/features/fundraising)
# [Allocation management](/features/allocation-management)
# [Token distributions](/features/token-vesting)
# [OTC marketplace](/features/otc-marketplace)
# [Investor portal](/features/investor-portal)
#
# Back office
#
# [Compliance](/features/compliance)
# [Spreadsheet import](/features/import)
#
# Use cases
#
# [Presail for investment groups](/use-cases/investment-groups)
# [Presail for projects](/use-cases/projects)
# [Presail for blockchains](/use-cases/blockchains)
#
# Resources
#
# [Help center](https://help.presail.com/en/)
# [Product tour video](/video-demo)
# [What is investment infrastructure?](/blog/what-is-investment-infrastructure-for-web-3-0)
# [Brand assets](https://drive.google.com/drive/folders/1nfHO_4wI3oO3RArjGwJ7w3oZQvohXDil?usp=sharing)
#
# Company
#
# [About us](/about-us)
# [Careers](https://careers.presail.com/)
#
# © 2021 - 2023 Presail. All rights reserved.
#
# [Privacy Policy](https://app.presail.com/privacy)
# [Terms of Service](https://app.presail.com/terms)
#
# [](https://twitter.com/presailcom)
# [](https://www.linkedin.com/company/presail-web3)
# Observation: {
#   "members": [
#     {
#       "name": "Michelle",
#       "role": "Head of Content",
#       "linkedin_page": "https://www.linkedin.com/in/michellejunewu/"
#     },
#     {
#       "name": "Emmanuel",
#       "role": "Senior Developer",
#       "linkedin_page": "https://www.linkedin.com/in/cousinemmanuel/"
#     },
#     {
#       "name": "Dan",
#       "role": "Senior Developer",
#       "linkedin_page": "https://www.linkedin.com/in/danbrooking"
#     },
#     {
#       "name": "Anna",
#       "role": "Principal Recruiter",
#       "linkedin_page": "https://www.linkedin.com/in/anna-serbo-/"
#     },
#     {
#       "name": "Håkon",
#       "role": "Customer Success",
#       "linkedin_page": "https://www.linkedin.com/in/h%C3%A5kon-%C3%B8verby-64534a22b/"
#     },
#     {
#       "name": "Glen",
#       "role": "Senior Frontend Developer",
#       "linkedin_page": "https://www.linkedin.com/in/glen-curtis-562439117/"
#     },
#     {
#       "name": "Pablo",
#       "role": "Web 3 Domain Specialist",
#       "linkedin_page": "https://www.linkedin.com/in/pabloruizdotco/"
#     },
#     {
#       "name": "Maral",
#       "role": "Head of Compliance",
#       "linkedin_page": "https://www.linkedin.com/in/maral-mirshahi-a1394440/"
#     },
#     {
#       "name": "Tomas",
#       "role": "CTO",
#       "linkedin_page": "https://www.linkedin.com/in/tomas-veiden/"
#     },
#     {
#       "name": "Hamza",
#       "role": "Head of Product",
#       "linkedin_page": "https://www.linkedin.com/in/hamzanebolsi/"
#     },
#     {
#       "name": "Xurxo",
#       "role": "Principal Developer",
#       "linkedin_page": "https://www.linkedin.com/in/xurxomendezperez/"
#     },
#     {
#       "name": "Milad",
#       "role": "COO",
#       "linkedin_page": "https://www.linkedin.com/in/milad-mirshahi/"
#     },
#     {
#       "name": "August",
#       "role": "Senior Developer",
#       "linkedin_page": "https://www.linkedin.com/in/august-haug-hem-74036b5a/"
#     },
#     {
#       "name": "Sebastian",
#       "role": "CEO",
#       "linkedin_page": "https://www.linkedin.com/in/sebastianalmnes/"
#     }
#   ]
# }
# Thought: I have gathered all the members of the company from the provided page. I can now present the information.
# Answer: Here are the members of the company from the provided page:
#
# 1. **Michelle** - Head of Content [LinkedIn](https://www.linkedin.com/in/michellejunewu/)
# 2. **Emmanuel** - Senior Developer [LinkedIn](https://www.linkedin.com/in/cousinemmanuel/)
# 3. **Dan** - Senior Developer [LinkedIn](https://www.linkedin.com/in/danbrooking)
# 4. **Anna** - Principal Recruiter [LinkedIn](https://www.linkedin.com/in/anna-serbo-/)
# 5. **Håkon** - Customer Success [LinkedIn](https://www.linkedin.com/in/h%C3%A5kon-%C3%B8verby-64534a22b/)
# 6. **Glen** - Senior Frontend Developer [LinkedIn](https://www.linkedin.com/in/glen-curtis-562439117/)
# 7. **Pablo** - Web 3 Domain Specialist [LinkedIn](https://www.linkedin.com/in/pabloruizdotco/)
# 8. **Maral** - Head of Compliance [LinkedIn](https://www.linkedin.com/in/maral-mirshahi-a1394440/)
# 9. **Tomas** - CTO [LinkedIn](https://www.linkedin.com/in/tomas-veiden/)
# 10. **Hamza** - Head of Product [LinkedIn](https://www.linkedin.com/in/hamzanebolsi/)
# 11. **Xurxo** - Principal Developer [LinkedIn](https://www.linkedin.com/in/xurxomendezperez/)
# 12. **Milad** - COO [LinkedIn](https://www.linkedin.com/in/milad-mirshahi/)
# 13. **August** - Senior Developer [LinkedIn](https://www.linkedin.com/in/august-haug-hem-74036b5a/)
# 14. **Sebastian** - CEO [LinkedIn](https://www.linkedin.com/in/sebastianalmnes/)
# AgentChatResponse(response='Here are the members of the company from the provided page:\n\n1. **Michelle** - Head of Content [LinkedIn](https://www.linkedin.com/in/michellejunewu/)\n2. **Emmanuel** - Senior Developer [LinkedIn](https://www.linkedin.com/in/cousinemmanuel/)\n3. **Dan** - Senior Developer [LinkedIn](https://www.linkedin.com/in/danbrooking)\n4. **Anna** - Principal Recruiter [LinkedIn](https://www.linkedin.com/in/anna-serbo-/)\n5. **Håkon** - Customer Success [LinkedIn](https://www.linkedin.com/in/h%C3%A5kon-%C3%B8verby-64534a22b/)\n6. **Glen** - Senior Frontend Developer [LinkedIn](https://www.linkedin.com/in/glen-curtis-562439117/)\n7. **Pablo** - Web 3 Domain Specialist [LinkedIn](https://www.linkedin.com/in/pabloruizdotco/)\n8. **Maral** - Head of Compliance [LinkedIn](https://www.linkedin.com/in/maral-mirshahi-a1394440/)\n9. **Tomas** - CTO [LinkedIn](https://www.linkedin.com/in/tomas-veiden/)\n10. **Hamza** - Head of Product [LinkedIn](https://www.linkedin.com/in/hamzanebolsi/)\n11. **Xurxo** - Principal Developer [LinkedIn](https://www.linkedin.com/in/xurxomendezperez/)\n12. **Milad** - COO [LinkedIn](https://www.linkedin.com/in/milad-mirshahi/)\n13. **August** - Senior Developer [LinkedIn](https://www.linkedin.com/in/august-haug-hem-74036b5a/)\n14. **Sebastian** - CEO [LinkedIn](https://www.linkedin.com/in/sebastianalmnes/)', sources=[ToolOutput(content='{\n  "members": [\n    {\n      "name": "Michelle",\n      "role": "Head of Content",\n      "linkedin_page": "https://www.linkedin.com/in/michellejunewu/"\n    },\n    {\n      "name": "Emmanuel",\n      "role": "Senior Developer",\n      "linkedin_page": "https://www.linkedin.com/in/cousinemmanuel/"\n    },\n    {\n      "name": "Dan",\n      "role": "Senior Developer",\n      "linkedin_page": "https://www.linkedin.com/in/danbrooking"\n    },\n    {\n      "name": "Anna",\n      "role": "Principal Recruiter",\n      "linkedin_page": "https://www.linkedin.com/in/anna-serbo-/"\n    },\n    {\n      "name": "Håkon",\n      "role": "Customer Success",\n      "linkedin_page": "https://www.linkedin.com/in/h%C3%A5kon-%C3%B8verby-64534a22b/"\n    },\n    {\n      "name": "Glen",\n      "role": "Senior Frontend Developer",\n      "linkedin_page": "https://www.linkedin.com/in/glen-curtis-562439117/"\n    },\n    {\n      "name": "Pablo",\n      "role": "Web 3 Domain Specialist",\n      "linkedin_page": "https://www.linkedin.com/in/pabloruizdotco/"\n    },\n    {\n      "name": "Maral",\n      "role": "Head of Compliance",\n      "linkedin_page": "https://www.linkedin.com/in/maral-mirshahi-a1394440/"\n    },\n    {\n      "name": "Tomas",\n      "role": "CTO",\n      "linkedin_page": "https://www.linkedin.com/in/tomas-veiden/"\n    },\n    {\n      "name": "Hamza",\n      "role": "Head of Product",\n      "linkedin_page": "https://www.linkedin.com/in/hamzanebolsi/"\n    },\n    {\n      "name": "Xurxo",\n      "role": "Principal Developer",\n      "linkedin_page": "https://www.linkedin.com/in/xurxomendezperez/"\n    },\n    {\n      "name": "Milad",\n      "role": "COO",\n      "linkedin_page": "https://www.linkedin.com/in/milad-mirshahi/"\n    },\n    {\n      "name": "August",\n      "role": "Senior Developer",\n      "linkedin_page": "https://www.linkedin.com/in/august-haug-hem-74036b5a/"\n    },\n    {\n      "name": "Sebastian",\n      "role": "CEO",\n      "linkedin_page": "https://www.linkedin.com/in/sebastianalmnes/"\n    }\n  ]\n}', tool_name='parse_member_page', raw_input={'args': (), 'kwargs': {'page_url': 'https://presail.com/about-us'}}, raw_output='{\n  "members": [\n    {\n      "name": "Michelle",\n      "role": "Head of Content",\n      "linkedin_page": "https://www.linkedin.com/in/michellejunewu/"\n    },\n    {\n      "name": "Emmanuel",\n      "role": "Senior Developer",\n      "linkedin_page": "https://www.linkedin.com/in/cousinemmanuel/"\n    },\n    {\n      "name": "Dan",\n      "role": "Senior Developer",\n      "linkedin_page": "https://ww ...

# %%
from llama_index.core.tools import FunctionTool
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.core.agent import ReActAgent

llm = AzureOpenAI(
    azure_deployment=chat_model,
    temperature=0.1,
    azure_endpoint=endpoint,
    api_key=api_key,
    api_version=api_version,
)

sys_msg_comp_members="""Get all the company members mentioned in the given page content. Return as a JSON with the key 'members' containing a list of dictionaries with keys 'name', 'role' and 'linkedin_page'. Note that when linkedIn page is not available, it should be an empty string.""" 

def parse_member_page(page_url: str):
    """
    This function scrapes a page containing information about members of a company.
    :param page_url: str, the url to scrape
    :return: 
    """
    member_page_content = scrape_firecrawl(page_url)
    # print(member_page_content)
    extracted_member_info = extract(member_page_content,sys_msg_comp_members)
    return extracted_member_info

def check_member_page_validity(members_page_url: str, company_page_url: str):
    """
    This function checks if the url of the members page if valid.
    Usually the members page is in the same domain as the company page.
    :param members_page_url: str, the url of the members page
    :param company_page_url: str, the url of the company page
    :return: 
    """
    members_page_url = members_page_url.strip("https://").strip("http://")
    company_page_url = company_page_url.strip("https://").strip("http://")
    if company_page_url in members_page_url:
        return True
    return False

def parse_company_page(page_url: str):
    """
    This function scrapes the main page of a company.
    :param page_url: str, the url to scrape
    :return:
    """
    company_page_content = scrape_firecrawl(page_url)
    extracted_company_info = extract(company_page_content, sys_msg_comp_overview)
    return extracted_company_info

member_scraping_tool = FunctionTool.from_defaults(fn=parse_member_page)
company_page_tool = FunctionTool.from_defaults(fn=parse_company_page)
member_page_validity_tool = FunctionTool.from_defaults(fn=check_member_page_validity)

agent = ReActAgent.from_tools([member_scraping_tool, company_page_tool, member_page_validity_tool], llm=llm, verbose=True)
# agent.chat("Get the information about the CEO and/or the founder of the company from this page https://presail.com/about-us")
agent.chat("Get me the overall information about the company, also the information of CEO and/or the founder of the company from this page https://presail.com/")
# Out:
# Thought: The current language of the user is English. I need to use a tool to help me answer the question.
# Action: parse_company_page
# Action Input: {'page_url': 'https://presail.com/'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 56
#      54 agent = ReActAgent.from_tools([member_scraping_tool, company_page_tool, member_page_validity_tool], llm=llm, verbose=True)
#      55 # agent.chat("Get the information about the CEO and/or the founder of the company from this page https://presail.com/about-us")
# ---> 56 agent.chat("Get me the overall information about the company, also the information of CEO and/or the founder of the company from this page https://presail.com/")
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/agent/runner/base.py:644, in AgentRunner.chat(self, message, chat_history, tool_choice)
#     639     tool_choice = self.default_tool_choice
#     640 with self.callback_manager.event(
#     641     CBEventType.AGENT_STEP,
#     642     payload={EventPayload.MESSAGES: [message]},
#     643 ) as e:
# --> 644     chat_response = self._chat(
#     645         message=message,
#     646         chat_history=chat_history,
#     647         tool_choice=tool_choice,
#     648         mode=ChatResponseMode.WAIT,
#     649     )
#     650     assert isinstance(chat_response, AgentChatResponse)
#     651     e.on_end(payload={EventPayload.RESPONSE: chat_response})
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/agent/runner/base.py:574, in AgentRunner._chat(self, message, chat_history, tool_choice, mode)
#     571 dispatch_event(AgentChatWithStepStartEvent(user_msg=message))
#     572 while True:
#     573     # pass step queue in as argument, assume step executor is stateless
# --> 574     cur_step_output = self._run_step(
#     575         task.task_id, mode=mode, tool_choice=tool_choice
#     576     )
#     578     if cur_step_output.is_last:
#     579         result_output = cur_step_output
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/agent/runner/base.py:411, in AgentRunner._run_step(self, task_id, step, input, mode, **kwargs)
#     407 # TODO: figure out if you can dynamically swap in different step executors
#     408 # not clear when you would do that by theoretically possible
#     410 if mode == ChatResponseMode.WAIT:
# --> 411     cur_step_output = self.agent_worker.run_step(step, task, **kwargs)
#     412 elif mode == ChatResponseMode.STREAM:
#     413     cur_step_output = self.agent_worker.stream_step(step, task, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/agent/react/step.py:738, in ReActAgentWorker.run_step(self, step, task, **kwargs)
#     735 @trace_method("run_step")
#     736 def run_step(self, step: TaskStep, task: Task, **kwargs: Any) -> TaskStepOutput:
#     737     """Run step."""
# --> 738     return self._run_step(step, task)
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/agent/react/step.py:535, in ReActAgentWorker._run_step(self, step, task)
#     533 chat_response = self._llm.chat(input_chat)
#     534 # given react prompt outputs, call tools or return response
# --> 535 reasoning_steps, is_done = self._process_actions(
#     536     task, tools, output=chat_response
#     537 )
#     538 task.extra_state["current_reasoning"].extend(reasoning_steps)
#     539 agent_response = self._get_response(
#     540     task.extra_state["current_reasoning"], task.extra_state["sources"]
#     541 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/agent/react/step.py:287, in ReActAgentWorker._process_actions(self, task, tools, output, is_streaming)
#     279 with self.callback_manager.event(
#     280     CBEventType.FUNCTION_CALL,
#     281     payload={
#    (...)
#     284     },
#     285 ) as event:
#     286     try:
# --> 287         tool_output = tool.call(**reasoning_step.action_input)
#     288     except Exception as e:
#     289         tool_output = ToolOutput(
#     290             content=f"Error: {e!s}",
#     291             tool_name=tool.metadata.name,
#    (...)
#     294             is_error=True,
#     295         )
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/llama_index/core/tools/function_tool.py:88, in FunctionTool.call(self, *args, **kwargs)
#      86 def call(self, *args: Any, **kwargs: Any) -> ToolOutput:
#      87     """Call."""
# ---> 88     tool_output = self._fn(*args, **kwargs)
#      89     return ToolOutput(
#      90         content=str(tool_output),
#      91         tool_name=self.metadata.name,
#      92         raw_input={"args": args, "kwargs": kwargs},
#      93         raw_output=tool_output,
#      94     )
#
# Cell In[42], line 47, in parse_company_page(page_url)
#      41 """
#      42 This function scrapes the main page of a company.
#      43 :param page_url: str, the url to scrape
#      44 :return:
#      45 """
#      46 company_page_content = scrape_firecrawl(page_url)
# ---> 47 extracted_company_info = extract(company_page_content, sys_msg_comp_overview)
#      48 return extracted_company_info
#
# Cell In[30], line 6, in extract(user_input, system_message)
#       3 messages = [entity_extraction_system_message]
#       4 messages.append({"role": "user", "content": user_input})
# ----> 6 response = client.chat.completions.create(
#       7       model="gpt-4o",
#       8       messages=messages,
#       9       stream=False,
#      10       response_format={"type": "json_object"}
#      11   )
#      13 return response.choices[0].message.content
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/openai/resources/chat/completions.py:590, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     558 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     559 def create(
#     560     self,
#    (...)
#     588     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     589 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 590     return self._post(
#     591         "/chat/completions",
#     592         body=maybe_transform(
#     593             {
#     594                 "messages": messages,
#     595                 "model": model,
#     596                 "frequency_penalty": frequency_penalty,
#     597                 "function_call": function_call,
#     598                 "functions": functions,
#     599                 "logit_bias": logit_bias,
#     600                 "logprobs": logprobs,
#     601                 "max_tokens": max_tokens,
#     602                 "n": n,
#     603                 "presence_penalty": presence_penalty,
#     604                 "response_format": response_format,
#     605                 "seed": seed,
#     606                 "stop": stop,
#     607                 "stream": stream,
#     608                 "stream_options": stream_options,
#     609                 "temperature": temperature,
#     610                 "tool_choice": tool_choice,
#     611                 "tools": tools,
#     612                 "top_logprobs": top_logprobs,
#     613                 "top_p": top_p,
#     614                 "user": user,
#     615             },
#     616             completion_create_params.CompletionCreateParams,
#     617         ),
#     618         options=make_request_options(
#     619             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     620         ),
#     621         cast_to=ChatCompletion,
#     622         stream=stream or False,
#     623         stream_cls=Stream[ChatCompletionChunk],
#     624     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/openai/_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/openai/_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/openai/_base_client.py:952, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     949 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     951 try:
# --> 952     response = self._client.send(
#     953         request,
#     954         stream=stream or self._should_stream_response_body(request=request),
#     955         **kwargs,
#     956     )
#     957 except httpx.TimeoutException as err:
#     958     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Library/Caches/pypoetry/virtualenvs/llamaindex-sample-BTxt78Z_-py3.10/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/ssl.py:1258, in SSLSocket.recv(self, buflen, flags)
#    1254     if flags != 0:
#    1255         raise ValueError(
#    1256             "non-zero flags not allowed in calls to recv() on %s" %
#    1257             self.__class__)
# -> 1258     return self.read(buflen)
#    1259 else:
#    1260     return super().recv(buflen, flags)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/ssl.py:1131, in SSLSocket.read(self, len, buffer)
#    1129         return self._sslobj.read(len, buffer)
#    1130     else:
# -> 1131         return self._sslobj.read(len)
#    1132 except SSLError as x:
#    1133     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
from IPython.display import display, Markdown

def company_info(url: str):
    info = agent.chat(f"Get me the overall information about the company, also the information of CEO and/or the founder of the company from this page {url}")
    return info.response

# %%
display(Markdown(company_info("https://vespa.ai/")))
# Out:
# Thought: The current language of the user is English. I need to use a tool to help me answer the question.
# Action: parse_company_page
# Action Input: {'page_url': 'https://vespa.ai/'}
# Observation: {
#     "company_goal": "Apply AI to your data, online. At any scale, with unbeatable performance.",
#     "company_summary": "Vespa is a fully featured search engine and vector database designed for large-scale data processing and AI applications. It supports a variety of search types, including vector search (ANN), lexical search, and structured data search, all integrated into a single query. It also supports real-time applications of AI via machine-learned model inference and provides high availability and performance. Companies like Spotify, Yahoo, and OTTO utilize Vespa for its capabilities in executing complex queries, recommendation systems, and structured navigation combining search and AI models.",
#     "established_time": "The specific establishment date is not provided in the provided text.",
#     "members_page": "https://vespa.ai/team"
# }
# Thought: I have gathered the overall information about the company. Now, I need to get the information about the CEO and/or the founder of the company from the members page.
# Action: parse_member_page
# Action Input: {'page_url': 'https://vespa.ai/team'}
# [![Vespa logo](https://vespa.ai/assets/logo.png)](/)
#
# [](https://search.vespa.ai/)
#
# [Get Started](https://cloud.vespa.ai/en/getting-started)
#  [Features](/features)
#
# Solutions
#
# [Vespa Executive Overview](/executive-overview.html)
#  [Unlocking eCommerce Growth](/unlocking-ecommerce-growth.html)
#
# Documentation
#
# [Vespa Overview Deck](https://docs.google.com/presentation/d/1TO_QX451CUvLzI3rVMcjB0qQXutUaoF6rTVfQLrfvPg)
#  [Vespa Documentation](https://docs.vespa.ai/)
#  [Video Archive](/resources)
#  [Vespa and ElasticSearch / Solr](/vespa-elastic-solr)
#
# [Blog](https://blog.vespa.ai/)
#
# Vespa Cloud
#
# [Vespa Cloud](https://cloud.vespa.ai/)
#  [Vespa Cloud Console](https://console.vespa.oath.cloud/)
#
# Company
#
# [About](/team)
#  [Jobs](/we-are-hiring)
#  [Events](/events)
#  [Press and news](/press)
#
# [Search](https://search.vespa.ai/)
#  [Slack](https://join.slack.com/t/vespatalk/shared_invite/zt-nq61o73o-Lsun7Fnm5N8uA6UAfIycIg)
#  [Github](https://github.com/vespa-engine/vespa)
#  [Help](/support)
#
# Vespa.ai team
# =============
#
# We are located in Trondheim, Norway, where we develop the open source Vespa platform, the automation behind Vespa Cloud, and help our users make use of it.
#
# [We're hiring!](we-are-hiring.html)
#
# ![Vespa team](https://vespa.ai/assets/photos/vespa-team.png)
#
# * * *
#
# Leadership
# ----------
#
# ![Jon Bratseth](https://vespa.ai/assets/photos/jon-bratseth.png)
#
# ### Jon Bratseth - founder and CEO
#
# The architect and one of the main contributors to Vespa. Jon has 20+ years experience as an architect and programmer on large distributed systems.
#
# ![Kim Johansen](https://vespa.ai/assets/photos/kim-johansen.jpg)
#
# ### Kim O. Johansen - founder and COO
#
# Head of the Vespa Core Team. Kim has 20+ years experience as a manager for development of large distributed systems.
#
# ![Frode Lundgren](https://vespa.ai/assets/photos/frode-lundgren.jpg)
#
# ### Frode Lundgren - founder and CTO
#
# Head of the Vespa Services team. 20+ years experience on managing teams using and operating large-, web-scale Vespa applications.
#
# ![Kristian Aune](https://vespa.ai/assets/photos/kristian-aune.jpg)
#
# ### Kristian Aune - founder and Head of Customer Success
#
# 20+ years working with Vespa application owners, developers, PMs, Ops - passionate about operations, cost, and serving quality.
#
# ![Tim Young](https://vespa.ai/assets/photos/tim-young.jpg)
#
# ### Tim Young - CMO
#
# 25+ years of experience marketing disruptive technology in AI, machine learning, big data, cloud and analytics markets.
#
# Contact us at [leadership@vespa.ai](mailto:leadership@vespa.ai)
# .
#
# Resources
#
# [Documentation](https://docs.vespa.ai/)
#
# [Open Source](https://github.com/vespa-engine/vespa)
#
# [Roadmap](/roadmap)
#
# [Releases](/releases)
#
# [Issues](https://github.com/vespa-engine/vespa/issues)
#
# [Privacy Policy](https://vespa.ai/product-terms/privacy-policy)
#
#
# Contact
#
# [Twitter](https://twitter.com/vespaengine)
#
# [info@vespa.ai](mailto:info@vespa.ai)
#
# [Vespa.ai team](/team)
#
# [We are hiring!](/we-are-hiring)
#
# [Mailing list](/mailing-list)
#
#
# Community
#
# [Slack](https://join.slack.com/t/vespatalk/shared_invite/zt-nq61o73o-Lsun7Fnm5N8uA6UAfIycIg)
#
# [Stack Overflow](https://stackoverflow.com/questions/tagged/vespa)
#
# [Contributing](https://github.com/vespa-engine/vespa/blob/master/CONTRIBUTING.md)
#
# [Blog](https://blog.vespa.ai/)
#
#
# ###### Copyright Vespa.ai
# Observation: {
#   "members": [
#     {
#       "name": "Jon Bratseth",
#       "role": "founder and CEO",
#       "linkedin_page": ""
#     },
#     {
#       "name": "Kim O. Johansen",
#       "role": "founder and COO",
#       "linkedin_page": ""
#     },
#     {
#       "name": "Frode Lundgren",
#       "role": "founder and CTO",
#       "linkedin_page": ""
#     },
#     {
#       "name": "Kristian Aune",
#       "role": "founder and Head of Customer Success",
#       "linkedin_page": ""
#     },
#     {
#       "name": "Tim Young",
#       "role": "CMO",
#       "linkedin_page": ""
#     }
#   ]
# }
# Thought: I can answer without using any more tools. I'll use the user's language to answer.
# Answer: ### Company Information
# **Company Name:** Vespa
# **Website:** [vespa.ai](https://vespa.ai)
# **Goal:** Apply AI to your data, online. At any scale, with unbeatable performance.
# **Summary:** Vespa is a fully featured search engine and vector database designed for large-scale data processing and AI applications. It supports a variety of search types, including vector search (ANN), lexical search, and structured data search, all integrated into a single query. It also supports real-time applications of AI via machine-learned model inference and provides high availability and performance. Companies like Spotify, Yahoo, and OTTO utilize Vespa for its capabilities in executing complex queries, recommendation systems, and structured navigation combining search and AI models.
# **Established Time:** The specific establishment date is not provided in the provided text.
#
# ### CEO and Founders Information
# - **Jon Bratseth**
#   - **Role:** Founder and CEO
#   - **LinkedIn:** Not provided
#
# - **Kim O. Johansen**
#   - **Role:** Founder and COO
#   - **LinkedIn:** Not provided
#
# - **Frode Lundgren**
#   - **Role:** Founder and CTO
#   - **LinkedIn:** Not provided
#
# - **Kristian Aune**
#   - **Role:** Founder and Head of Customer Success
#   - **LinkedIn:** Not provided
#
# ### Other Key Members
# - **Tim Young**
#   - **Role:** CMO
#   - **LinkedIn:** Not provided
#
# This information provides a comprehensive overview of the company and its key personnel.
# ### Company Information
# **Company Name:** Vespa
# **Website:** [vespa.ai](https://vespa.ai)
# **Goal:** Apply AI to your data, online. At any scale, with unbeatable performance.
# **Summary:** Vespa is a fully featured search engine and vector database designed for large-scale data processing and AI applications. It supports a variety of search types, including vector search (ANN), lexical search, and structured data search, all integrated into a single query. It also supports real-time applications of AI via machine-learned model inference and provides high availability and performance. Companies like Spotify, Yahoo, and OTTO utilize Vespa for its capabilities in executing complex queries, recommendation systems, and structured navigation combining search and AI models.
# **Established Time:** The specific establishment date is not provided in the provided text.
#
# ### CEO and Founders Information
# - **Jon Bratseth**
#   - **Role:** Founder and CEO
#   - **LinkedIn:** Not provided
#
# - **Kim O. Johansen**
#   - **Role:** Founder and COO
#   - **LinkedIn:** Not provided
#
# - **Frode Lundgren**
#   - **Role:** Founder and CTO
#   - **LinkedIn:** Not provided
#
# - **Kristian Aune**
#   - **Role:** Founder and Head of Customer Success
#   - **LinkedIn:** Not provided
#
# ### Other Key Members
# - **Tim Young**
#   - **Role:** CMO
#   - **LinkedIn:** Not provided
#
# This information provides a comprehensive overview of the company and its key personnel.
